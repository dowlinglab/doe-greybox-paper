# %% [markdown]
# # Membrane model parameter estimation
# This notebook is used to get the estimates of the parameters of the membrane model

# %%
from membrane_experiment import membrane_parameter_estimation

# estimate the parameters and covariance matrix
theta, cov = membrane_parameter_estimation()
# Out:
# WARNING (W1002): Setting Var 'fs.stage1.permeate[0.0,1].flow_vol' to a numeric
# value `0.0` outside the bounds (1e-08, None).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.stage1.permeate[0.0,2].flow_vol' to a numeric
# value `0.0` outside the bounds (1e-08, None).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.stage1.permeate[0.0,3].flow_vol' to a numeric
# value `0.0` outside the bounds (1e-08, None).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.stage1.permeate[0.0,4].flow_vol' to a numeric
# value `0.0` outside the bounds (1e-08, None).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var 'fs.stage1.permeate[0.0,5].flow_vol' to a numeric
# value `0.0` outside the bounds (1e-08, None).
# ...

# %%
print("The parameter estimates are:\n", theta)
print("\n The covariance matrix is:\n", cov)
# Out:
# The parameter estimates are:
#  fs.Lp                            2.974121e-07
# fs.constant_sieving_coeff[Li]    1.328554e+00
# fs.constant_sieving_coeff[Co]    4.910421e-01
# fs.ionic_strength_coeff[Li]      5.139832e-04
# fs.ionic_strength_coeff[Co]      1.337537e-04
# dtype: float64
#
#  The covariance matrix is:
#                                        fs.Lp  fs.constant_sieving_coeff[Li]  \
# fs.Lp                          1.052582e-17                  -2.603445e-10
# fs.constant_sieving_coeff[Li] -2.603445e-10                   1.314306e-02
# fs.constant_sieving_coeff[Co]  3.617392e-11                  -1.973078e-03
# fs.ionic_strength_coeff[Li]    1.996316e-13                  -1.680464e-05
# fs.ionic_strength_coeff[Co]    6.050573e-14                  -3.439046e-06
#
#                                fs.constant_sieving_coeff[Co]  \
# fs.Lp                                           3.617392e-11
# fs.constant_sieving_coeff[Li]                  -1.973078e-03
# ...
